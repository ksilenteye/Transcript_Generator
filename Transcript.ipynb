# %%
# !pip install assemblyai
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLError(1, '[SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:1000)'))': /simple/assemblyai/
# Collecting assemblyai
#   Downloading assemblyai-0.40.2-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: httpx>=0.19.0 in /opt/anaconda3/lib/python3.12/site-packages (from assemblyai) (0.27.0)
# Requirement already satisfied: pydantic>=1.10.17 in /opt/anaconda3/lib/python3.12/site-packages (from assemblyai) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.7 in /opt/anaconda3/lib/python3.12/site-packages (from assemblyai) (4.11.0)
# Collecting websockets>=11.0 (from assemblyai)
#   Downloading websockets-15.0.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.19.0->assemblyai) (4.2.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.19.0->assemblyai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.19.0->assemblyai) (1.0.2)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.19.0->assemblyai) (3.7)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.19.0->assemblyai) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.19.0->assemblyai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic>=1.10.17->assemblyai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.12/site-packages (from pydantic>=1.10.17->assemblyai) (2.20.1)
# Downloading assemblyai-0.40.2-py3-none-any.whl (44 kB)
# Downloading websockets-15.0.1-cp312-cp312-macosx_11_0_arm64.whl (173 kB)
# Installing collected packages: websockets, assemblyai
# Successfully installed assemblyai-0.40.2 websockets-15.0.1

# %%
import assemblyai as aai

aai.settings.api_key = "2c6bce08d218433088273ded882aee78"
audio_file = "bus.mp4"
config = aai.TranscriptionConfig(speech_model=aai.SpeechModel.best)

transcript = aai.Transcriber(config=config).transcribe(audio_file)

if transcript.status == "error":
  raise RuntimeError(f"Transcription failed: {transcript.error}")

print(transcript.text)
# Out:
# If you're worried about buying a business that will drain your savings and take years to be profitable, you're not alone. That is the number one fear I hear from people that are looking to buy their first business. But after doing seven acquisitions myself and helping hundreds of students to do the same, I can tell you that there is a clear formula for finding businesses that will put money in your pocket on day one. Today I'm going to show you exactly how to find those cash flowing opportunities and avoid the money pits that trap first time buyers. Here's the right approach when it comes to finding the right business. Number one, you're going to focus on existing cash flow, not potential. This is one of the biggest traps that most people get themselves into. They look at a business, they think of all the things that they can do to make this business better. You do not value a business on potential. You value a business on past performance, the last three years of performance. Whatever potential you think it has, that is no value. The only value it has is what it's done. That's the only thing you can point towards. That is the hard data. You want to look for stability over growth potential. We want businesses that have a steady revenue growth and steady cash flow growth. We do not want businesses that show an erratic chart of one year they're up, the next year they're down. We always prioritize the stability, not the sexiness of the business itself. And which leads me to saying that I like boring rather than exciting. Because boring is something that is consistent, has some type of recurring value to it and people need it. Which is why we think it's boring. Because all of us know what it is. We have all used it before. It's not exciting, right? All of us think AI and all these cool new startup ideas. Yeah, that's exciting, but that's not what we want to buy. That's a lot of risk. High risk, high reward. We want things that are low risk but also have an amazing reward. And that's what we're going after Now. Here is the wrong approach. This is what I do not want you to do do. Buying a turnaround or fixer upper. When we come to businesses, there's going to be a lot of businesses you look at that are turnarounds or fixer uppers. They're just not good, they're losing money, they're barely making money. They have horrible operations, a horrible product. There are people who have skill sets that are suited to that and they are the minority. They're very special people that Take on that risk and they know what they're doing. That is not you. That is not me. Even after all the experience I have now, I would never take on a turnaround or a fixer upper. Do not trace trends. Something comes out, it's a new concept or hey, it's, it's now, you know the pet cleaning business, but now it has AI with it. All that throw it to the side. You focus on simple, understandable businesses. Another big mistake is thinking that you're going to figure it out after buying it. No, you're going to figure it out during the due diligence phase before you buy it. Because if you can't figure it out or it's not as good as you thought, you're going to be able to get away scot free, not lose money, not waste your time and not waste your energy. You're not going to figure it out after purchasing it. That needs to be all figured out before the purchase. Last believe that you can quickly improve operations. Not going to happen. Now there are certain people out there that have just gurus at operations. They're amazing at it and they can do a lot of fixing in a short period of time. That is not 99% of us, myself included. It doesn't take a short period of time, it takes a long period of time to make operations work well. So when you're focusing in on what your projections might be or what the business is going to do, or how much time you're going to put into it, always double that amount of time you think it's going to be. And probably it's going to be longer than that ...
